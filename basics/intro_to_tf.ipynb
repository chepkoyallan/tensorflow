# %% [markdown]
# ## Tensorflow Introduction
#
#     * An open source, *high-performance library* for *numerical computation* that uses *directed graphs*
#     * Writen in a very high level language (python) and exwcuted in a very fas way (C++)
#     * A DAG is created to represent the computation that you do
#     * The nodes represents the mathematical operations
#     * The edges representing the input and output of the mathematical operations
#     * The edges represents arrays of data flowing towards the output
#     * The array of data flowing arround
#
#
# ## A Tensor as an N-dimenssional array of data
#
#     * Rank 0 tensor, Scalar
#     * Rank 1 tensor vector
#     * Rank 2 tensor matrix
#     * Rank 3 tensor
#     * Rank 4 tensor
#
# * Why use directed acyclic graphs (portability) DAG language independednt represention of the code in your model
# * Python -> saved model -> c++ -> cpu -> gpu language and hardware portability
# * Tensorflow execution engine
#
#
#
# ![image.png](attachment:8b0e1d09-e9bd-459c-bdde-3b7074f2ae50.png)
#
# ## The tensorflow API
#
# ![image.png](attachment:440f1913-eeff-4248-9e4e-568fdc062890.png)
#
# *
# *
# *
# *
